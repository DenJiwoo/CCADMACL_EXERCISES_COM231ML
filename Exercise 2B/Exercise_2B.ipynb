# %% [markdown]
# # EXERCISE 2B
#
# Imagine you are a data scientist working for an international development organization. Your team wants to understand how countries differ in terms of economy, health, and social well-being. You have access to a dataset containing multiple indicators for countries worldwide, such as GDP per capita, life expectancy, child mortality, and population.
#
# Your task is to discover natural groupings of countries using hierarchical clustering. By examining these clusters, you can identify patterns such as:
#
# - Which countries are economically developed or developing
#
# - How social and health indicators vary across regions
#
# - Surprising similarities between countries from different continents
#
# Answer each question by completing the corresponding code cell. **Do not remove or reorder cells.**
#
# Dataset feature description
#
#  - child mort - Death of children under 5 years of age per 1000 live births
#
# - exports - Exports of goods and services per capita. Given as %age of the GDP per capita
# - health - Total health spending per capita. Given as %age of GDP per capita
# - import - Imports of goods and services per capita. Given as %age of the GDP per capita
# - income - Net income per person
# - inflation - The measurement of the annual growth rate of the Total GDP
# - life_expec - The average number of years a new born child would live if the current mortality patterns are to remain the same
# - total_fer - The number of children that would be born to each woman if the current age-fertility rates remain the same.
# - gdpp - The GDP per capita. Calculated as the Total GDP divided by the total population.

# %%
import kagglehub
import os

# Download latest version
path = kagglehub.dataset_download("rohan0301/unsupervised-learning-on-country-data")

print("Path to dataset files:", path)

if os.path.isdir(path):
  print(True)

contents = os.listdir(path)
contents

mydataset = path + "/" + contents[0]
mydataset


df = pd.read_csv(mydataset)
# Out:
# Using Colab cache for faster access to the 'unsupervised-learning-on-country-data' dataset.
# Path to dataset files: /kaggle/input/unsupervised-learning-on-country-data
# True

# %% [markdown]
# ## 1. Import Required Libraries
# Import the core libraries needed for data analysis, visualization, and clustering.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AgglomerativeClustering

# %% [markdown]
# ## 2. Load the Dataset
# Upload the CSV file for *the* **Country Data** dataset.

# %%
import kagglehub
import os

# Download latest version
path = kagglehub.dataset_download("rohan0301/unsupervised-learning-on-country-data")

print("Path to dataset files:", path)

if os.path.isdir(path):
  print(True)

contents = os.listdir(path)
contents

mydataset = path + "/" + contents[0]
mydataset


df = pd.read_csv(mydataset)
# Out:
# Using Colab cache for faster access to the 'unsupervised-learning-on-country-data' dataset.
# Path to dataset files: /kaggle/input/unsupervised-learning-on-country-data
# True

# %% [markdown]
# ## 3. Exploring the Dataset

# %% [markdown]
# Display the first 10 rows of the dataset `(5 pts)`
#
# - Show the initial records to understand the dataset's structure and variables.

# %%
df.head(10)
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# 5            Argentina        14.5     18.9    8.10     16.0   18700
# 6              Armenia        18.1     20.8    4.40     45.3    6700
# 7            Australia         4.8     19.8    8.73     20.9   41400
# 8              Austria         4.3     51.3   11.00     47.8   43200
# 9           Azerbaijan        39.2     54.3    5.88     20.7   16000
#
#    inflation  life_expec  total_fer   gdpp
# 0      9.440        56.2       5.82    553
# 1      4.490        76.3       1.65   4090
# 2     16.100        76.5       2.89   4460
# 3     22.400        60.1       6.16   3530
# 4      1.440        76.8       2.13  12200
# 5     20.900        75.8       2.37  10300
# 6      7.770        73.3       1.69   3220
# 7      1.160        82.0       1.93  51900
# 8      0.873        80.5       1.44  46900
# 9     13.800        69.1       1.92   5840

# %% [markdown]
# Display the shape of the dataset `(5 pts)`
# - How many rows (countries) and how many features does the dataset contain?

# %%
print(df.shape)
# Out:
# (167, 10)

# %% [markdown]
# Show summary statistics using `describe()`. `(5 pts)`

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# 50%      5.390000   73.100000    2.410000    4660.000000
# 75%     10.750000   76.800000    3.880000   14050.000000
# max    104.000000   82.800000    7.490000  105000.000000

# %% [markdown]
# Check for missing values. `(5 pts)`

# %%
df.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %% [markdown]
# ## 4. Data Preprocessing

# %% [markdown]
# Select only the numerical columns for clustering `(5 pts)`
# - Exclude any non-numeric fields, such as 'Country Name' or categorical variables.

# %%
numerical_df = df.drop('country', axis=1)

# %% [markdown]
# Standardize the selected numerical features `(5 pts)`
#
# - This ensures all features contribute equally to the distance calculations used in clustering.

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_df)

# %% [markdown]
# ## 5. Exploratory Data Analysis

# %% [markdown]
# Generate a correlation heatmap
# - Visualize the relationships between socioeconomic indicators. `(10 pts)`

# %%
correlation_matrix = numerical_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Identify 2–3 variables that appear strongly correlated `(10 pts)`
# - Explain your observations in the text cell below.

# %%
# Based on the correlatoin heatmap above I was able to identify that the most suitable variable from the correlation values are life expectancy, GDPP, Child mortality.

# %%
print(correlation_matrix.loc[['gdpp', 'life_expec', 'child_mort'], ['gdpp', 'life_expec', 'child_mort']])
# Out:
#                 gdpp  life_expec  child_mort
# gdpp        1.000000    0.600089   -0.483032
# life_expec  0.600089    1.000000   -0.886676
# child_mort -0.483032   -0.886676    1.000000

# %%
import plotly.express as px

fig = px.scatter_3d(numerical_df, x="gdpp", y="life_expec", z="child_mort",
                    title='3D Scatter Plot of GDP per Capita, Life Expectancy, and Child Mortality')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f23a8f2f-ddb1-44da-9dcc-a771c29860e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f23a8f2f-ddb1-44da-9dcc-a771c29860e5")) {                    Plotly.newPlot(                        "f23a8f2f-ddb1-44da-9dcc-a771c29860e5",                        [{"hovertemplate":"gdpp=%{x}\u003cbr\u003elife_expec=%{y}\u003cbr\u003echild_mort=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[553,4090,4460,3530,12200,10300,3220,51900,46900,5840,28000,20700,758,16000,6030,44400,4340,758,2180,1980,4610,6350,11200,35300,6840,575,231,786,1310,47400,3310,446,897,12900,4560,6250,769,334,2740,8200,1220,13500,30800,19800,58000,5450,4660,2600,2990,17100,482,14600,3650,46200,40600,8750,562,2960,41800,1310,26900,7370,2830,648,547,3040,662,13100,41900,1350,3110,6530,4500,48700,30600,35800,4680,44500,3680,9070,967,1490,38500,880,1140,11300,8860,1170,327,12100,12000,105000,4540,413,459,9070,7100,708,21100,1200,8000,2860,1630,2650,6680,2830,419,988,5190,592,50300,33700,348,2330,87800,19300,1040,8080,3230,5020,2130,12600,22500,70300,8230,10700,563,3450,19300,1000,5410,10800,399,46600,16600,23400,1290,7280,22100,30700,2810,6230,1480,8300,52100,74600,738,702,5080,3600,488,3550,4140,10700,4440,595,2970,35000,38900,48400,11900,1380,2970,13500,1310,1310,1460],"y":[56.2,76.3,76.5,60.1,76.8,75.8,73.3,82.0,80.5,69.1,73.8,76.0,70.4,76.7,70.4,80.0,71.4,61.8,72.1,71.6,76.8,57.1,74.2,77.1,73.9,57.9,57.7,66.1,57.3,81.3,72.5,47.5,56.5,79.1,74.6,76.4,65.9,57.5,60.4,80.4,56.3,76.3,79.9,77.5,79.5,74.6,76.7,70.5,74.1,60.9,61.7,76.0,65.3,80.0,81.4,62.9,65.5,72.8,80.1,62.2,80.4,71.3,71.3,58.0,55.6,65.5,32.1,74.5,82.0,66.2,69.9,74.5,67.2,80.4,81.4,81.7,74.7,82.8,75.8,68.4,62.8,60.7,78.2,68.5,63.8,73.1,79.8,46.5,60.8,76.1,73.2,81.3,74.0,60.8,53.1,74.5,77.9,59.5,80.3,68.2,73.4,65.4,69.7,66.2,76.4,73.5,54.5,66.8,58.6,68.3,80.7,80.9,58.8,60.5,81.0,76.1,65.3,77.8,74.1,77.9,69.0,76.3,79.8,79.5,73.7,69.2,64.6,71.5,75.1,64.0,74.7,73.4,55.0,82.7,75.5,79.5,61.7,54.3,80.1,81.9,74.4,71.6,66.3,70.3,81.5,82.2,69.6,59.3,76.6,71.1,58.7,69.9,76.9,78.2,67.9,56.8,70.4,76.5,80.3,78.7,76.4,68.8,63.0,75.4,73.1,67.5,52.0],"z":[90.2,16.6,27.3,119.0,10.3,14.5,18.1,4.8,4.3,39.2,13.8,8.6,49.4,14.2,5.5,4.5,18.8,111.0,42.7,46.6,6.9,52.5,19.8,10.5,10.8,116.0,93.6,44.4,108.0,5.6,26.5,149.0,150.0,8.7,15.7,18.6,88.2,116.0,63.9,10.2,111.0,5.5,3.6,3.4,4.1,34.4,25.1,29.1,19.2,111.0,55.2,4.5,24.1,3.0,4.2,63.7,80.3,16.5,4.2,74.7,3.9,14.6,35.4,109.0,114.0,37.6,208.0,6.0,2.6,58.8,33.3,19.3,36.9,4.2,4.6,4.0,18.1,3.2,21.1,21.5,62.2,62.7,10.8,29.6,78.9,7.8,10.3,99.7,89.3,16.6,6.1,2.8,10.4,62.2,90.5,7.9,13.2,137.0,6.8,97.4,15.0,40.0,17.2,26.1,6.8,33.5,101.0,64.4,56.0,47.0,4.5,6.2,123.0,130.0,3.2,11.7,92.1,19.7,24.1,20.3,31.9,6.0,3.9,9.0,11.5,10.0,63.6,18.9,15.7,66.8,7.6,14.4,160.0,2.8,7.0,3.2,28.1,53.7,4.1,3.8,11.2,20.7,76.7,24.1,3.0,4.5,52.4,71.9,14.9,62.6,90.3,17.4,17.4,19.1,62.0,81.0,11.7,8.6,5.2,7.3,10.6,36.3,29.2,17.1,23.3,56.3,83.1],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111," ...

# %% [markdown]
# ## 6. Hierarchical Clustering

# %% [markdown]
# Compute and display a dendrogram using the linkage method `(10 pts)`
# - Use `'ward'` linkage to minimize variance within clusters.

# %%
z = linkage(scaled_data, method='ward')
plt.figure(figsize=(10,4))
dendrogram(z)
plt.title('Dendrogram')
plt.xlabel('Countries')
plt.ylabel('Distance')
# Out:
# Text(0, 0.5, 'Distance')

# %% [markdown]
# Based on the dendrogram, choose a reasonable number of clusters `(5 pts)`
# - Write your chosen number below and explain your reasoning.

# %%
#Based on the linkage dendrogram, I have chosen 3 clusters, via identifying the distance of each clusters from each other on the dendrogram.

# %% [markdown]
# Perform Agglomerative Clustering using your chosen cluster count `(10 pts)`
# - Attach the cluster labels back to the original dataframe.

# %%
n_clusters = 3
hc = AgglomerativeClustering(n_clusters=n_clusters, metric='euclidean', linkage='ward')

df['cluster'] = hc.fit_predict(scaled_data)

print(df[['country', 'cluster']].head())
# Out:
#                country  cluster
# 0          Afghanistan        2
# 1              Albania        1
# 2              Algeria        1
# 3               Angola        1
# 4  Antigua and Barbuda        1

# %% [markdown]
# ## 7. Visualizing Cluster Results

# %% [markdown]
# Create a scatter plot using any 2 meaningful features, colored by cluster `(10 pts)`
# - Choose variables that make socioeconomic sense (e.g., GDP per capita vs. life expectancy).

# %%
plt.title('Scatter Plot of GDP per Capita vs. Life Expectancy by Cluster')
plt.xlabel('GDP per Capital')
plt.ylabel('Life Expectancy')
plt.scatter(df['gdpp'], df['life_expec'], c=df['cluster'], cmap='viridis')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# There are a total 3 formed clusters. Those clusters being developed countries, developing countries, least developed countries.

# %% [markdown]
# *Write you answer here*

# %% [markdown]
# ## 8. Reflection
# Write a short reflection on what socioeconomic insights hierarchical clustering revealed about global development patterns. `(10 pts)`

# %% [markdown]
# Each of the 3 clusters are denominated by 3 variables which are GDP, Low life expectancy, and child mortality. Those 3 clusters being Developed countries, Developing Countries, and Least Developed countries. These are all higly effected base on the number of the 3 variables mentioned. Meaning that based on the 3 variables we can see how a cluster of countries are doing socioeconomically.
